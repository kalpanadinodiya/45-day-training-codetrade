# %%
import timeit

# %%
x = timeit.timeit(stmt='[1,2,3,4,5]',number=10000)

# %%
print(x)
# Out:
# 0.0016426999354735017

# %%
y = timeit.timeit(stmt='(1,2,3,4,5)',number=10000)

# %%
print(y)
# Out:
# 0.00029699993319809437

# %%
lis = [12,41,2,247]

# %%
lis1 = [23,45,65,57]

# %%
lis+lis1
# Out:
# [12, 41, 2, 247, 23, 45, 65, 57]

# %%
lis = [[]]*5

# %%
lis
# Out:
# [[], [], [], [], []]

# %%
dir of lis
# Out:
#   Cell In[11], line 1
#     dir of lis
#         ^
# SyntaxError: invalid syntax

# %%
# append
add the element at last index
# Out:
#   Cell In[12], line 2
#     add the element at last index
#         ^
# SyntaxError: invalid syntax

# %%
lis.append(99)

# %%
lis=[12,341,35,246,99]

# %%
lis.append(77)

# %%
lis
# Out:
# [12, 341, 35, 246, 99, 77]

# %%
lis pop()
# Out:
#   Cell In[17], line 1
#     lis pop()
#         ^
# SyntaxError: invalid syntax

# %%
lis.pop()
# Out:
# 77

# %%
lis
# Out:
# [12, 341, 35, 246, 99]

# %%
lis.pop(1)
# Out:
# 341

# %%
lis
# Out:
# [12, 35, 246, 99]

# %%
lis[-1].append(99)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 lis[-1].append(99)
#
# AttributeError: 'int' object has no attribute 'append'

# %%
lis []*5
# Out:
#   Cell In[23], line 1
#     lis []*5
#          ^
# SyntaxError: invalid syntax

# %%
lis = [[]]*5

# %%
lis
# Out:
# [[], [], [], [], []]

# %%
lis[-1].append(99)

# %%
lis
# Out:
# [[99], [99], [99], [99], [99]]
